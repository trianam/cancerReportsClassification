# %%
# %matplotlib notebook
import funPytorch as fun
import configurationsPrimeTest as configurations
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 5]

# %%
# centers = [20,30,40,50,60,70,80,90,100,110,120,130,140,150,160,170,180,190,200,210,220,230,240,250,260]
# confs = {
#     "max":{c:configurations.config48[c] for c in centers},
#     "base":{c:configurations.config49[c] for c in centers},
# }

centers = [100,200,300,400,500,600,700,800,900,1000]
confs = {
    "MAX":{c:configurations.config50l[c] for c in centers},
    "ATT":{c:configurations.config64l[c] for c in centers},
    "MAXi":{c:configurations.config63l[c] for c in centers},
    "GRU":{c:configurations.config51l[c] for c in centers},
}

# %%
maxes = {k:{c:fun.getMaxTest(confs[k][c]) for c in centers} for k in confs.keys()}
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1114 18:16:11.746579 139699478689600 deprecation.py:323] From /home/trianam/miniconda3/lib/python3.7/site-packages/tensorflow/python/summary/summary_iterator.py:68: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
plt.figure()
#plt.title("Maximum test accuracy")
for k in confs.keys():
    plt.plot(sorted(centers),[maxes[k][c] for c in sorted(centers)], label=k)
ax = plt.gca()
ax.minorticks_on()
ax.grid(which='major', linestyle='-', color='k')
ax.grid(which='minor', linestyle='--')
plt.xlabel(r"$m$")
plt.ylabel("accuracy")
plt.legend()
plt.show()
plt.savefig("tmp/maxBaseDiff.eps", bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# W1114 18:16:12.262741 139699478689600 backend_ps.py:804] The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# W1114 18:16:12.263666 139699478689600 backend_ps.py:804] The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# W1114 18:16:12.379608 139699478689600 backend_ps.py:804] The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# W1114 18:16:12.380409 139699478689600 backend_ps.py:804] The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
