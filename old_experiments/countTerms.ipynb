# %%
import numpy as np
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open("./corpusLSTM_ICDO3/text.txt", 'r') as f:
    wc = Counter(" ".join(f.readlines()).strip().split())

# %%
wc.most_common()
# Out:
# [('#num#', 659228),
#  ('.', 569417),
#  (')', 519940),
#  ('di', 336877),
#  ('(', 298311),
#  ('-', 296415),
#  (',', 244017),
#  (';', 190866),
#  (':', 175614),
#  ('cm', 139237),
#  ('e', 118297),
#  ('a', 106040),
#  ('con', 95949),
#  ('in', 70542),
#  ('del', 68799),
#  ('linfonodi', 66964),
#  ('della', 66430),
#  ('margine', 65179),
#  ('mm', 59683),
#  ('margini', 55510),
#  ('carcinoma', 54119),
#  ("'", 51855),
#  ('neoplasia', 48095),
#  ('#vol#', 44747),
#  ('%', 40899),
#  ('+', 39232),
#  ('frammento', 37255),
#  ('lesione', 36895),
#  ('neoplastica', 36552),
#  ('la', 35542),
#  ('#sur#', 33814),
#  ('chirurgica', 33667),
#  ('grado', 33649),
#  ('neoformazione', 31827),
#  ('i', 31529),
#  ('proliferazione', 31495),
#  ('infiltrante', 31204),
#  ('cellule', 30964),
#  ('frammenti', 30299),
#  ('nei', 30214),
#  ('adenocarcinoma', 30057),
#  ('nessuna', 27571),
#  ('il', 27396),
#  ('diametro', 27160),
#  ('per', 27080),
#  ('/', 25593),
#  ('intestinale', 25315),
# ...

# %%
x = []
y = []
c = [0]
for i,e in enumerate(wc.most_common()):
    #print(e)
    x.append(i+1)
    y.append(e[1])
    c.append(c[-1]+e[1])
c = c[1:]
p = list(map(lambda x: x/c[-1], c))

# %%
plt.figure()
plt.plot(x,c)
plt.show()

# %%
plt.figure()
plt.plot(x[:1000],c[:1000])
plt.show()

# %%
fig = plt.figure()
ax = fig.gca()
ax.set_xticks(np.arange(0,40000,5000))
ax.set_yticks(np.arange(0,1.05,0.05))
plt.plot(x,p)
plt.ylim([0.,1.05])
plt.savefig("/tmp/fig1.pdf", bbox_inches='tight')
plt.show()

# %%
fig = plt.figure()
ax = fig.gca()
ax.set_xticks(np.arange(0,1100,100))
ax.set_yticks(np.arange(0,1.05,0.05))
plt.plot(x[:1000],p[:1000])
plt.ylim([0.,1.05])
plt.savefig("/tmp/fig2.pdf", bbox_inches='tight')
plt.show()

# %%
#cutoff = 5350
cutoff = 500
print(c[-1])
print(c[cutoff])
print(c[-1]-c[cutoff])
print((c[-1]-c[cutoff])/c[-1]*100)
# Out:
# 9264143
# 7879038
# 1385105
# 14.951248053921448

# %%
p[500]
# Out:
# 0.8504875194607855

# %%
len(x)
# Out:
# 35216

# %%
c[-1]
# Out:
# 9264143
